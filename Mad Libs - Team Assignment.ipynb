# %%
# Team Introductions for Python 

print("Welcome to Team 5 introductions for MBAN Python Class!")

print()

# applying the argument < prompt > to get user name
user_name = input(prompt = "What's your name? ")

print()

print(f"""Hi there {user_name} great to see you are interested in learning 
more about our team and watching our code run!""")

print()

# introducing interactive portion of our intro
print("""Its going to be interactive, so come along for the ride and 
learn some more about us.""")

print()

print("""We are going to play a little Mad Libs, so we need a few things 
from you.""")

print()

# applying optional argument < prompt > for mad lib inputs 
noun = input(prompt = "Give a noun (specifically a thing). ")
place = input(prompt = "Name a place. ")
type_of_drink = input(prompt = "Name your favorite drink. ")

print()

print("But lets also guess who's who, with these little clues. ")

print()

#applying the optional argument < prompt > for name guessing game input
print("Skiing and cooking is my passion. ")
julia = input(prompt = """Who am I?
""")

print()

print("I love taco's and REAL football. ")
fernando = input(prompt = """Who am I?
""")

print()

print("Dogs and swimming are my thing ")
gaby = input(prompt = """Who am I?
""")

print()

print("I am a geek and a jock.")
lars = input(prompt = """Who am I? 
""")

print()

print("I love comics and anime. ")
yusuke = input(prompt = """Who am I?
""")

print()

print("""Let's hear our story, with your inputs... 
""")

#dynamically applying user inputs
print(f"""In 2020 we all packed our {noun} and left for an exciting new 
adventure in {place}. After 10 months, late nights 
studying and drinking {type_of_drink} we were done our first degree and looking 
forward to our next - an MBAN, we heard that this degree was going to be 
challenging. Here's our team:
""")

print(f"""{julia}, the Canadian team member, loves skiing and has never gone a 
year of her life (except the first) without hitting the slopes - she actually 
snowboards too.
""")

print(f"""{fernando},the Mexican team member is a food lover, especially 
spicy tacos. He is also in love with sports and when he 
isn’t studying or working, he is watching all kinds. 
""")

print(f"""{gaby}, our girl from Costa Rica is a big dog, lover. 
She also loves to swim at the beach with her friends and family. 
""")

print(f"""{lars}, our Norwegian team member. He likes soccer and sweets, 
but not the US corn syrup type! In his spare time he loves to watch ANY 
type of tv show... 
""")

print(f"""{yusuke}, our Japanese team member who loves manga and anime, was
also raised by Doraemon. He loves golf and tennis, both watching and 
playing. 
""")

print("Guessed correctly? How do you think you did - check below! ")
# Out:
# Welcome to Team 5 introductions for MBAN Python Class!
#
# What's your name? Juan
#
# Hi there Juan great to see you are interested in learning
# more about our team and watching our code run!
#
# Its going to be interactive, so come along for the ride and
# learn some more about us.
#
# We are going to play a little Mad Libs, so we need a few things
# from you.
#
# Give a noun (specifically a thing). iPhone
# Name a place. Bahamas
# Name your favorite drink. Piña Colada
#
# But lets also guess who's who, with these little clues.
#
# Skiing and cooking is my passion.
# Who am I?
# Yusuke
#
# I love taco's and REAL football.
# Who am I?
# Gaby
#
# Dogs and swimming are my thing
# Who am I?
# Lars
#
# I am a geek and a jock.
# Who am I?
# Fernando
#
# I love comics and anime.
# Who am I?
# Julia
#
# Let's hear our story, with your inputs...
#
# In 2020 we all packed our iPhone and left for an exciting new
# adventure in Bahamas. After 10 months, late nights
# ...
