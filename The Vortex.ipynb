# %% [markdown]
# ### Welcome to "The Vortex" an adventure text game were you could be the hero or the villain of a true story.
#
# Next you will have the responsibility to save the course of humanity.

# %%
#### Introduction ###
def introduction():
    print("""It is late 2019 in Wuhang, China. You are a researcher of British origin 
who is doing an investigation in this Asian city and unfortunately, there is an 
outbreak of a deadly virus that attacks the respiratory tract. You are officially 
considered patient zero and the future of humanity and reality as we know it now 
depends on you.
Now it is time to go back to your country, but the symptoms have started, you feel 
extreme fatigue, headache, chills, but you think it is a normal cold and the only 
thing you think about is being back home with your family. However, if you decide 
to take the flight back home, there is a high probability that you will infect 
whoever passes near you.\n""")

    
## Constructing first setting, Wuhang.###
def wuhang():
    input(prompt = f'Ready to save humanity {user_name.capitalize()}? (Press enter to continue)\n')
    hotel_room() #this moves player to the hotel room where the game beggins.

## Adding setting number 2, hotel_room ##
def hotel_room():
    print("""\nNow you find yourself in the hotel room feeling sick and the fact 
of not knowing if it is a common cold or it could be that you are infected with 
the virus, makes you consider two options. Which one would you pick? 
(Pick an option) 
a) Take the plane back home 
b) Stay at the hotel""")
    choice = input(prompt = '>').casefold()

    if choice == 'a' or 'take the plane back home' in choice:
        plan_a() #this takes player to Plan A which means fly back home.

    elif choice == 'b' or 'stay at the hotel' in choice:
        print ('\nWell done! You are one step closer to save millions of lives.')
        plan_b()#this takes player to Plan B, which means save humanity.

    else:
        print("\nInvalid entry. Please try again.\n")
        hotel_room() #Forces user to try again same question.
            

## Defining plan A - the path to tragedy ##
def plan_a():
    print("""\nYou've decided to ignore symptoms and head to the airport to catch 
your plane. Now you must be very carefull. Are you sure you want to go 
home? (Pick one option) 
a) Yes
b) No\n""")
    choice = input(prompt = '>').casefold()
    if choice == 'a' or choice == 'yes':
        airport() 
   
    elif choice == 'b' or choice == 'no':
        hotel_room()
    
    else:
        print("\nInvalid entry. Please try again.")
        plan_a() # forces user to choose either a or b.

## Defining plan B - anonymous hero ##
def plan_b():
    print("""\nAs mentioned before, given the fact that the news in China is 
saying that a new virus might impact the world, you don't know if your symptoms 
might be caused by that virus or just a simple cold.""")
    
    print("""\nWhat should you do next? (Pick one option)     
a) Stay at the hotel and don't see anybody.
b) Wash my hand frequently.
c) Drink lots of water and electrolytes.""")
    
    choice = input (prompt = '>')
    ### Any of the options is correct. ###
    if choice == 'a' or choice == 'b' or choice == 'c': 
        print ('\nExcellent! You should do that and also consider the other options.')
        hotel_room_2()
    else:
        print('Invalid entry. Please try again.\n')
        plan_b()

        
### Defining next day at hotel room ###
def hotel_room_2(): 
    print("""\nThe next morning the symptoms become even more intense and now you have a fever. 
No energy for anything and you need help now! This time you have 4 options:
a) Go to the airport and fly home no matter what.
b) Call room service.
c) Get out of the room and look for help.
d) Nothing and wait to feel better.
""")
    choice = input (prompt = '>')
    
    if choice == 'a': #Sends you to the airport. Takes plan A.
        airport()
        
    elif choice == 'b': #Makes you call for an ambulance and go to Wuhang's General Hospital
        print('Good idea! Try to ask for everything you can.')
        print("""\nAfter 2 days at the hotel room, the sickness is real and 
extreme, you can't even sleep and you have difficulty breathing. """)
        
        ### Defining the chances to call an ambulance. The user must be able to 
        # call an ambulance in three chances, if not it will fail and the pandemic will 
        # start either way.
        whg_emergency_number = 119 
        chances = 3
        while chances > 0:
            choice = input (prompt = "Type 119 to call an ambulance. You have only 3 chances.\n")
            try:
                choice = int (choice) #converting choice for numerical comparison
            except:
                print('Wrong number. Try using numeric values such as 1, 2, 3, etc. ')
    
            if choice == whg_emergency_number: #Guessed correctly, goes to the hospital.
                hospital_wuhang()
                break
                
            elif choice != whg_emergency_number: #Wrong number, try again.
                chances -= 1
            if chances > 0:
                print (f"That's not the correct number, you have {chances} left. Please try again.\n" )
            elif chances == 0:
                print("\nYou're out of chances. You fail\n")
                fail()
                
    elif choice == 'c': #Makes you call for an ambulance and go to Wuhang's General Hospital
        print('Not so clever. Remember you could spread this deadly virus.')
        print("""\nAfter 2 days at the hotel room now the sickness is real and 
extreme, you can't even sleep and you now have difficulty breathing. """)
        
        ### Defining the chances to call an ambulance. The user must be able to 
        # call an ambulance in three chances, if not it will fail and the pandemic will 
        # start either way.
        whg_emergency_number = 119
        chances = 3
        while chances > 0:
            choice = input (prompt = "Type 119 to call an ambulance. You have only 3 chances.\n")
            try:
                choice = int (choice) #converting choice for numerical comparison
            except:
                print('Wrong number. Try using numeric values such as 1, 2, 3, etc. ')
            
            if choice == whg_emergency_number: #Guessed correctly, goes to the hospital.
                hospital_wuhang()
                break
                
            elif choice != whg_emergency_number: #Wrong number, try again.
                chances -= 1
            if chances > 0:
                print (f"That's not the correct number, you have {chances} left. Please try again.\n" )
            elif chances == 0:
                print("\nYou're out of chances. You fail\n")
                fail()
                
    elif choice == 'd': #Makes you call for an ambulance and go to Wuhang's General Hospital
        print('Good but this will only get worse.')
        print("""\nAfter 2 days at the hotel room now the sickness is real and 
extreme, you can't even sleep and you now have difficulty breathing. """)
 
        ### Defining the chances to call an ambulance. The user must be able to 
        # call an ambulance in three chances, if not it will fail and the pandemic will 
        # start either way.
        whg_emergency_number = 119
        chances = 3
        while chances > 0:
            choice = input (prompt = f"Type 119 to call an ambulance. You have only {chances} chances.\n")
            try:
                choice = int (choice) #converting choice for numerical comparison
            except:
                print('Wrong number. Try using numeric values such as 1, 2, 3, etc. ')
            
            if choice == whg_emergency_number: #Guessed correctly, goes to the hospital.
                hospital_wuhang()
                break
                
            elif choice != whg_emergency_number: #Wrong number, try again.
                chances -= 1 #This subtracts one chance.
            if chances > 0:
                print (f"That's not the correct number, you have {chances} left. Please try again.\n" )
            elif chances == 0:
                print("\nYou're out of chances. You fail\n")
                fail()
    else:
        print ("\nInvalid entry. Please try again.\n")
        hotel_room_2() # forces user to choose either a, b, c or d.
        
### defining airport ###
def airport():
    print(f"""\nYou don't know this yet {user_name.capitalize()} but you are now considered 
a biological weapon. Now you need to be extra careful and try to protect everyone 
around you. For this you can do the following: (Choose one option)
a) Use a facemask and cover your nose and mouth at all times.
b) Ignore everyone around you even if they ask you something.
c) Pray, pray, pray. (even if not religious)""")
    choice = input (prompt = 'Choose only one option\n')
    if choice == 'a':
        print('\nExactly. That is one of the best ways to prevent a virus from spreading.')
        london()
        
    elif choice == 'b':
        print ('\nNot so polite but still works to prevent virus from spreading.')
        london()
        
    elif choice == 'c':
        print ("\nSorry but that's not very useful on this ocation. Try again.") 
        #forces player to choose either a or b.
        airport()
    else:
        print ("\nInvalid entry. Please try again.")
        airport()
        
### Defining arrival to London ####
def london():
    print("""\nNow you have arrived home and you might feel safe but what you 
don't know is that now you've spread the virus all over the world! The 
pandemic has officially began! """)
    input (prompt = 'Press enter to continue')
    
    print("""\nThe next day at home, the sickness is real and extreme, you 
can't even sleep and you have difficulty breathing. You are 
extreamly worried and you need to go to the hospital.""")
    
        ### Defining the chances to call an ambulance. The user must be able to 
        # call an ambulance in three chances, if not it will fail and the pandemic will 
        # start either way.
    ldn_emergency_number = 999
    chances = 3
    while chances > 0:
        choice = None
        while True:
            try:
                choice = int (choice)
                break
            except TypeError:
                choice = input (prompt = f"Type 999 to call an ambulance. You have {chances} chances.\n")
            except ValueError:
                print('Invalid number, try again')
                chances -= 1
                
                if chances == 0:
                    print("\nYou're out of chances. You fail\n")
                    fail()
                else:
                    print('Please just use numeric values.')
                    choice = input (prompt = f"Type 999 to call an ambulance. You have {chances} chances.\n")
                    
        if choice == ldn_emergency_number: #Guessed correctly, goes to the hospital.
            london_hospital()
            break 
            
        elif choice != ldn_emergency_number: #Wrong number, try again.
            chances -= 1
        if chances > 0:
            print (f"\nThat's not the correct number, you have {chances} left. Please try again.\n" )
        elif chances == 0:
            print("\nYou're out of chances. You fail\n")
            fail()
        else:
            print('Invalid entry. Please just use numeric values.')
            london()
            
### Here the user has no way back but to die and GAME OVER. ###
def game_over():    
    print(f"""\nSorry to tell you this {user_name.capitalize()} but now you are intubated 
and unconsious. It's a matter of time until you die.\n""")
    choice = input (prompt = 'Type "RIP" ').casefold()
    if choice == "rip":
        print ('\nGAME OVER!')
    else:
        print ('Invalid entry. Try again.')
        game_over()
    
### Defining Wuhang's General Hospital ###
def hospital_wuhang():
    print("""\nYou are now at Wuhang's General Hospital and doctors are very 
concerned about your case, this is something they haven't seen before and your 
symptoms are very weird.""")
    print("""\nThe next day at the hospital you are intubated but you heard in the 
news that after a long research of your case at the hospital, your virus 
is a new type of Coronavirus that is highly contagious and lethal on elderly people. 
The good thing is that the virus hasn't spread and everything seems to be under 
control thanks to your good decisions and your prudence.""")
    input (prompt = 'Press enter to continue.')
    hero()
    
### This is where the user becomes a hero and saves humanity ###
def hero():
    print("""\nThere is nothing left to do and you are about to die, but you 
are considered a hero and thanks to you, the world is safe and there were 
no casualties. """)
    choice = input (prompt = 'Type "HERO" to continue.\n').casefold()
    if choice == 'hero':
        print (f'\n Congratulations {user_name.capitalize()}. YOU WON!')
        
    else:
        print ('Invalid entry. Try again.')
        hero() 
    
    input(prompt = '<Press enter to start again>\n')
    wuhang()

### Defining London hospital ###
def london_hospital():
    print("""\nThe next day at the hospital you can barely read the news and 
you realize that now the virus is all over the world and things are getting 
out of control.""")
    input (prompt = 'Press enter to continue')
    print(f"""\nSorry to tell you this {user_name.capitalize()} but now you are intubated 
and unconsious. It's a matter of time until you die.\n""")
    choice = input (prompt = 'Type "RIP" ').casefold()
    if choice == "rip":
        print ("\nGAME OVER!")  
    else:
        print ('Invalid entry. Try again.')
        game_over()
        
    input('<Press enter to start again>\n')
    wuhang()
    
### Defining the fail function ###
def fail():
    print("You've failed, the pandemic will develop anyway.")
    input('<Press enter to start again>\n')
    wuhang()

introduction()

#Defining the first variable ###
user_name = input (prompt = 'How do you like to be called? ').capitalize()
if user_name == "":
    print("\nOk, you will be called Butthead")
    user_name = "Butthead"
    
wuhang()  # Calling the first function in our map will start our game
